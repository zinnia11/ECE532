# %% [markdown]
# # Activity 18

# %% [markdown]
# ---
# ## Setup
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def prxgraddescent_l1(X,y,tau,lam,w_init,it):

## compute it iterations of L2 proximal gradient descent starting at w1
## w_{k+1}= (w_k - tau*X'*(X*w_k - y)/(1+lam*tau)
## step size tau
    W = np.zeros((w_init.shape[0], it+1))
    Z = np.zeros((w_init.shape[0], it+1))
    W[:,[0]] = w_init
    for k in range(it):
        Z[:,[k+1]] = W[:,[k]] - tau * X.T @ (X @ W[:,[k]] - y);
        W[:,[k+1]] = np.sign(Z[:,[k+1]])* np.clip(
            np.abs(Z[:,[k+1]])-lam*tau/2,0,float("inf"))
        
    return W,Z

# %%
## Proximal gradient descent trajectories
## Least Squares Problem
X = np.array([[2, 1]])
y = np.array([[4]])

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w2)):
    for j in range(len(w1)):
        w = np.array([ [w1[j]], [w2[i]] ])
        fw[i,j] = (X @ w - y)**2

### Plot the countours
plt.figure(num=None, figsize=(4, 4), dpi=120)      
plt.contour(w1,w2,fw,20)
plt.xlim([-1,3])
plt.ylim([-1,3])
plt.xlabel('$w_1$')
plt.ylabel('$w_2$')
plt.axis('square');

# %% [markdown]
# ---
# ## Question 3a)
# ---

# %%
## Find and display weights generated by gradient descent

w_init = np.array([[0],[0]])
lam = 4;
it = 10
tau = 0.25
W,Z = prxgraddescent_l1(X,y,tau,lam,w_init,it)
# Concatenate gradient and regularization steps to display trajectory
G = np.zeros((2,0))
for i in range(it):
    G = np.hstack((G,np.hstack((W[:,[i]],Z[:,[i+1]]))))

print(W)
print(W[:, it])

plt.figure(figsize=(7,7))
plt.contour(w1,w2,fw,20)
plt.plot(Z[0,1::],Z[1,1:],'bx',linewidth=2, label="Gradient Descent Step")
plt.plot(W[0,:],W[1,:],'ro',linewidth=2, label="Regularization Step")
plt.plot(G[0,:],G[1,:],'-c',linewidth=2)
plt.legend()
plt.xlabel('w_1')
plt.ylabel('w_2')
plt.title('$\\tau = $'+str(tau)+', $\lambda = $'+str(lam));
# Out:
# [[0.     1.5    1.25   1.4375 1.5    1.5    1.5    1.5    1.5    1.5
#   1.5   ]
#  [0.     0.5    0.125  0.     0.     0.     0.     0.     0.     0.
#   0.    ]]
# [1.5 0. ]

# %% [markdown]
# ---
# ## Question 3b)
# ---

# %%
## Find and display weights generated by gradient descent

w_init = np.array([[0],[0]])
lam = 2;
it = 10
tau = 0.25
W,Z = prxgraddescent_l1(X,y,tau,lam,w_init,it)
# Concatenate gradient and regularization steps to display trajectory
G = np.zeros((2,0))
for i in range(it):
    G = np.hstack((G,np.hstack((W[:,[i]],Z[:,[i+1]]))))

print(W)
print(W[:, it])

plt.figure(figsize=(6,6))
plt.contour(w1,w2,fw,20)
plt.plot(Z[0,1::],Z[1,1:],'bx',linewidth=2, label="Gradient Descent Step")
plt.plot(W[0,:],W[1,:],'ro',linewidth=2, label="Regularization Step")
plt.plot(G[0,:],G[1,:],'-c',linewidth=2)
plt.legend()
plt.xlabel('w_1')
plt.ylabel('w_2')
plt.title('$\\tau = $'+str(tau)+', $\lambda = $'+str(lam));
# Out:
# [[0.         1.75       1.375      1.53125    1.5546875  1.61132812
#   1.65966797 1.71008301 1.75       1.75       1.75      ]
#  [0.         0.75       0.4375     0.390625   0.27734375 0.18066406
#   0.07983398 0.         0.         0.         0.        ]]
# [1.75 0.  ]

# %% [markdown]
# ---
# ## Question 4)
# ---

# %%
## Find and display weights generated by gradient descent

w_init = np.array([[0],[0]])
lam = 4;
it = 2
tau = 0.1
W,Z = prxgraddescent_l1(X,y,tau,lam,w_init,it)
# Concatenate gradient and regularization steps to display trajectory
G = np.zeros((2,0))
for i in range(it):
    G = np.hstack((G,np.hstack((W[:,[i]],Z[:,[i+1]]))))

print(W)
print(W[:, it])

plt.figure(figsize=(7,7))
plt.contour(w1,w2,fw,20)
plt.plot(Z[0,1::],Z[1,1:],'bx',linewidth=2, label="Gradient Descent Step")
plt.plot(W[0,:],W[1,:],'ro',linewidth=2, label="Regularization Step")
plt.plot(G[0,:],G[1,:],'-c',linewidth=2)
plt.legend()
plt.xlabel('w_1')
plt.ylabel('w_2')
plt.title('$\\tau = $'+str(tau)+', $\lambda = $'+str(lam));
# Out:
# [[0.   0.6  0.92]
#  [0.   0.2  0.26]]
# [0.92 0.26]
